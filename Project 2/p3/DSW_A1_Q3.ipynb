# %% [markdown]
# # Q3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

book_data = pd.read_csv('/content/prog_book.csv')
print("Number of null records in the reviews column:", book_data['Reviews'].isnull().sum())
book_data['Reviews'] = book_data.Reviews.str.replace(',', '').astype(float)
book_data['Reviews'].describe()
# Out:
# Number of null records in the reviews column: 0
# count     271.000000
# mean      185.557196
# std       552.122252
# min         0.000000
# 25%         5.500000
# 50%        35.000000
# 75%       116.500000
# max      5938.000000
# Name: Reviews, dtype: float64

# %% [markdown]
# ## Task 1

# %%
univariate_outlier_features = ['Rating', 'Reviews', 'Number_Of_Pages', 'Price']
colors = ['blue', 'green', 'yellow', 'red']

for i, feature in enumerate(univariate_outlier_features):
  plt.figure(figsize=(15,8))
  ax = sns.boxplot(book_data[feature], color=colors[i], linewidth=2.5, fliersize=8, orient='h')
  ax.set_title(f'Box plot for {feature}')
  ax.set_xlabel(f'{feature}')
  outliers = plt.scatter([],[], marker="d", color="gray", s=30, label="Outliers")
  plt.legend(handles=[outliers])
  plt.tight_layout()
  plt.show()

# %% [markdown]
# ## Task 2

# %%
print("Categories in the Type column:", book_data['Type'].unique())
book_data['Type_Numeric'] = book_data['Type'].astype('category').cat.codes
# Out:
# Categories in the Type column: ['Hardcover' 'Kindle Edition' 'Paperback' 'ebook' 'Unknown Binding'
#  'Boxed Set - Hardcover']

# %%
features = ['Rating', 'Reviews', 'Number_Of_Pages', 'Type_Numeric', 'Price']
dbscan_data = book_data[features]
data_scaled = StandardScaler().fit_transform(dbscan_data)
data = pd.DataFrame(data_scaled, columns = dbscan_data.columns)

# %% [markdown]
# ### Bivariate Analysis

# %%
for first in range(5):
  for second in range(first+1, 5):
    x = data[[features[first], features[second]]].values
    db = DBSCAN(eps=0.5, min_samples=5)
    db.fit(x)
    outliers_in_cols = data[db.labels_==-1].index.to_numpy()
    plt.figure(figsize=(10,6))
    plt.scatter(x[:,0], x[:,1], c=db.labels_)
    plt.scatter(x[outliers_in_cols,0], x[outliers_in_cols,1], c='black', label='Outliers')
    plt.xlabel(features[first])
    plt.ylabel(features[second])
    plt.title(f"Bivariate Analysis of {features[first]} and {features[second]}")
    plt.tight_layout()
    plt.legend()
    plt.show()

    if len(outliers_in_cols) > 0:
      print("\n")
      print(f"Outliers in the bivariate analysis of {features[first]} and {features[second]}:")
      display(data.iloc[outliers_in_cols, [first, second]])
    print("\n")
# Out:
# Outliers in the bivariate analysis of Rating and Reviews:
#        Rating    Reviews
# 0    0.353476   6.611187
# 1   -0.197845   2.214547
# 3   -0.335676   2.671812
# 4   -0.025557   2.067569
# 6    0.077816  10.438061
# 7    0.284561   2.960325
# 8   -0.680252   3.461139
# 13  -0.680252   1.940551
# 19   0.112273   3.459324
# 23   0.732510   1.964140
# 45   0.698053   4.433735
# 52  -0.197845   1.541351
# 54   3.213457  -0.336702
# 90  -0.060015   3.818604
# 122 -0.094472   1.016948
# 131  2.248645   0.320163
# 138  1.146001   1.251024
# 177 -3.678063  -0.336702
# 182 -3.678063  -0.336702
# 187 -3.678063  -0.336702
# Outliers in the bivariate analysis of Rating and Number_Of_Pages:
#        Rating  Number_Of_Pages
# 2   -2.540962        -1.391042
# 24  -2.988911        -0.514027
# 54   3.213457        -0.517300
# 60  -2.575420        -0.108244
# 86  -2.919996         2.372267
# 131  2.248645         0.461161
# 132 -2.403132        -0.618745
# 137  1.904069         3.373635
# 177 -3.678063        -0.036250
# 182 -3.678063        -0.049340
# 187 -3.678063        -0.926355
# 194  2.076357         1.037111
# 203 -0.370133         2.418082
# 226 -1.645064         0.958572
# 232 -1.024828         2.182466
# 260 -2.127471         1.848677
# 269  2.420933         8.812435
# Outliers in the bivariate analysis of Rating and Type_Numeric:
#        Rating  Type_Numeric
# 2   -2.540962     -0.294619
# 4   -0.025557     -0.294619
# 48  -0.025557     -0.294619
# 54   3.213457      2.556872
# 58   0.973713     -0.294619
# 71  -1.059285     -0.294619
# 72   0.284561     -0.294619
# 78   0.319019      2.556872
# 85   0.146731      1.606375
# 88   0.835883      2.556872
# 95  -0.680252      1.606375
# 104  0.939256     -0.294619
# 107  0.284561      2.556872
# 127 -0.818082     -0.294619
# 136 -0.473506     -0.294619
# 153  0.939256     -0.294619
# 166 -0.542421      2.556872
# 177 -3.678063      0.655878
# 182 -3.678063      0.655878
# 187 -3.678063      0.655878
# 228  1.318289      2.556872
# 229 -0.163388      2.556872
# 268  1.456120     -2.195613
# 269  2.420933     -1.245116
# Outliers in the bivariate analysis of Rating and Price:
#        Rating     Price
# 9    1.904069 -1.119374
# 54   3.213457 -0.804757
# 132 -2.403132 -0.249040
# 177 -3.678063  0.127379
# 182 -3.678063  0.164097
# 184 -1.886268  0.172265
# 187 -3.678063  0.185880
# 213 -1.748437  0.631526
# 226 -1.645064  0.780625
# 227 -2.024098  0.802573
# 255 -1.369404  1.433788
# 260 -2.127471  1.779925
# 261 -0.852540  1.814002
# 263 -1.024828  2.381601
# 264 -0.852540  2.485483
# 265  0.663595  3.411430
# 266 -1.059285  4.167898
# 267 -0.439048  4.420054
# 268  1.456120  4.652572
# 269  2.420933  4.652572
# 270 -0.783624  5.080809
# Outliers in the bivariate analysis of Reviews and Number_Of_Pages:
#        Reviews  Number_Of_Pages
# 0     6.611187        -1.211057
# 3     2.671812        -0.268594
# 6    10.438061        -0.716919
# 7     2.960325        -0.350405
# 8     3.461139        -0.707101
# 19    3.459324         0.219000
# 45    4.433735        -0.425671
# 90    3.818604        -0.298046
# 119   0.380043         1.436349
# 137  -0.285894         3.373635
# 269  -0.329444         8.812435
# Outliers in the bivariate analysis of Reviews and Type_Numeric:
#        Reviews  Type_Numeric
# 0     6.611187     -1.245116
# 1     2.214547     -1.245116
# 3     2.671812     -1.245116
# 4     2.067569     -0.294619
# 6    10.438061     -1.245116
# 7     2.960325     -1.245116
# 8     3.461139     -1.245116
# 13    1.940551     -1.245116
# 19    3.459324     -1.245116
# 23    1.964140      0.655878
# 45    4.433735     -1.245116
# 52    1.541351      0.655878
# 85   -0.109884      1.606375
# 90    3.818604      0.655878
# 95   -0.115327      1.606375
# 138   1.251024      0.655878
# 268  -0.271378     -2.195613
# Outliers in the bivariate analysis of Reviews and Price:
#        Reviews     Price
# 0     6.611187 -1.268555
# 6    10.438061 -1.130843
# 7     2.960325 -1.127130
# 8     3.461139 -1.123252
# 19    3.459324 -1.046764
# 45    4.433735 -0.849560
# 90    3.818604 -0.488159
# 138   1.251024 -0.223544
# 265  -0.327629  3.411430
# Outliers in the bivariate analysis of Number_Of_Pages and Type_Numeric:
#      Number_Of_Pages  Type_Numeric
# 2          -1.391042     -0.294619
# 85         -0.612200      1.606375
# 95         -0.867451      1.606375
# 137         3.373635     -1.245116
# 228         1.020749      2.556872
# 229         0.349898      2.556872
# 268         1.377445     -2.195613
# 269         8.812435     -1.245116
# Outliers in the bivariate analysis of Number_Of_Pages and Price:
#      Number_Of_Pages     Price
# 86          2.372267 -0.502846
# 137         3.373635 -0.229567
# 203         2.418082  0.374007
# 262         1.050201  2.020942
# 263         0.745863  2.381601
# 264         0.614966  2.485483
# 265         2.486803  3.411430
# 266         0.906213  4.167898
# 267         1.848677  4.420054
# 268         1.377445  4.652572
# 269         8.812435  4.652572
# 270         1.027293  5.080809
# Outliers in the bivariate analysis of Type_Numeric and Price:
#      Type_Numeric     Price
# 85       1.606375 -0.516625
# 95       1.606375 -0.455732
# 228      2.556872  0.804058
# 229      2.556872  0.804306
# 265     -1.245116  3.411430
# 266     -1.245116  4.167898
# 267      0.655878  4.420054
# 268     -2.195613  4.652572
# 269     -1.245116  4.652572
# 270     -1.245116  5.080809

# %% [markdown]
# ### Trivariate Analysis

# %%
for first in range(5):
  for second in range(first+1, 5):
    for third in range(second+1, 5):
      x = data[[features[first], features[second], features[third]]].values
      db = DBSCAN(eps=0.5, min_samples=5)
      db.fit(x)
      outliers_in_cols = data[db.labels_==-1].index.to_numpy()
      fig = plt.figure(figsize=(15,8))
      ax = plt.subplot(111, projection='3d')
      ax.scatter(x[:,0], x[:,1], x[:,2], c=db.labels_)
      ax.scatter(x[outliers_in_cols,0], x[outliers_in_cols,1], x[outliers_in_cols,2], c='black', label='Outliers')
      ax.set_xlabel(features[first])
      ax.set_ylabel(features[second])
      ax.set_zlabel(features[third])
      plt.title(f"Trivariate Analysis of {features[first]}, {features[second]}, and {features[third]}")
      plt.tight_layout()
      plt.legend()
      plt.show()

      if len(outliers_in_cols) > 0:
        print("\n")
        print(f"Outliers in the trivariate analysis of {features[first]}, {features[second]}, and {features[third]}:")
        display(data.iloc[outliers_in_cols, [first, second, third]])
      print("\n")
# Out:
# Outliers in the trivariate analysis of Rating, Reviews, and Number_Of_Pages:
#        Rating    Reviews  Number_Of_Pages
# 0    0.353476   6.611187        -1.211057
# 1   -0.197845   2.214547         0.169913
# 2   -2.540962  -0.336702        -1.391042
# 3   -0.335676   2.671812        -0.268594
# 4   -0.025557   2.067569        -0.556569
# 6    0.077816  10.438061        -0.716919
# 7    0.284561   2.960325        -0.350405
# 8   -0.680252   3.461139        -0.707101
# 9    1.904069  -0.336702        -1.135791
# 11  -0.990370   0.536094        -0.402764
# 13  -0.680252   1.940551        -0.481303
# 19   0.112273   3.459324         0.219000
# 21  -1.231573   0.889930        -0.762733
# 23   0.732510   1.964140        -0.206417
# 24  -2.988911  -0.336702        -0.514027
# 45   0.698053   4.433735        -0.425671
# 52  -0.197845   1.541351        -0.402764
# 54   3.213457  -0.336702        -0.517300
# 60  -2.575420  -0.331258        -0.108244
# 67   1.146001   0.655854        -0.245687
# 86  -2.919996  -0.333073         2.372267
# 90  -0.060015   3.818604        -0.298046
# 229 -0.163388         0.349898      2.556872
# 232 -1.024828         2.182466     -1.245116
# 253  0.146731         2.162831      0.655878
# 257 -0.680252         0.814585      0.655878
# 260 -2.127471         1.848677     -1.245116
# 265  0.663595         2.486803     -1.245116
# 267 -0.439048         1.848677      0.655878
# 268  1.456120         1.377445     -2.195613
# 269  2.420933         8.812435     -1.245116
# Outliers in the trivariate analysis of Rating, Number_Of_Pages, and Price:
#        Rating  Number_Of_Pages     Price
# 2   -2.540962        -1.391042 -1.214015
# 9    1.904069        -1.135791 -1.119374
# 24  -2.988911        -0.514027 -0.992801
# 54   3.213457        -0.517300 -0.804757
# 60  -2.575420        -0.108244 -0.748814
# 86  -2.919996         2.372267 -0.502846
# 94  -2.368674        -0.042795 -0.457464
# 119  0.766968         1.436349 -0.334604
# 125  1.490577         0.258269 -0.283777
# 129 -0.370133         1.743958 -0.258529
# 131  2.248645         0.461161 -0.251928
# 132 -2.403132        -0.618745 -0.249040
# 134 -0.128930         1.154919 -0.239633
# 137  1.904069         3.373635 -0.229567
# 147 -1.679522         0.310628 -0.113060
# 155 -0.818082         1.230185 -0.086079
# 177 -3.678063        -0.036250  0.127379
# 182 -3.678063        -0.049340  0.164097
# 184 -1.886268         0.039016  0.172265
# 187 -3.678063        -0.926355  0.185880
# 193 -1.266031         0.173186  0.260718
# 194  2.076357         1.037111  0.267897
# 198  1.766238         1.269454  0.330440
# 201 -0.232303         0.827674  0.344798
# 203 -0.370133         2.418082  0.374007
# 213 -1.748437        -0.000254  0.631526
# 215 -0.990370        -0.425671  0.670306
# 222 -0.060015        -0.199873  0.767175
# 226 -1.645064         0.958572  0.780625
# 227 -2.024098        -0.284956  0.802573
# 228  1.318289         1.020749  0.804058
# 232 -1.024828         2.182466  0.871470
# 233 -0.542421        -0.298046  0.917512
# 240  0.904798         2.306819  1.058029
# 245  0.973713         1.887946  1.163974
# 246  1.042629        -0.144241  1.176929
# 249 -0.128930         1.901036  1.270497
# 251  1.214917         1.645785  1.364313
# 252  0.146731         1.639240  1.372399
# 253  0.146731         2.162831  1.372399
# 255 -1.369404        -0.370040  1.433788
# 256  0.215646         1.508343  1.492619
# 258  0.319019         2.162831  1.648484
# 259  0.387934         2.149741  1.717133
# 260 -2.127471         1.848677  1.779925
# 261 -0.852540         0.736046  1.814002
# 262  0.043358         1.050201  2.020942
# 263 -1.024828         0.745863  2.381601
# 264 -0.852540         0.614966  2.485483
# 265  0.663595         2.486803  3.411430
# 266 -1.059285         0.906213  4.167898
# 267 -0.439048         1.848677  4.420054
# 268  1.456120         1.377445  4.652572
# 269  2.420933         8.812435  4.652572
# 270 -0.783624         1.027293  5.080809
# Outliers in the trivariate analysis of Rating, Type_Numeric, and Price:
#        Rating  Type_Numeric     Price
# 2   -2.540962     -0.294619 -1.214015
# 4   -0.025557     -0.294619 -1.160795
# 9    1.904069      0.655878 -1.119374
# 24  -2.988911      0.655878 -0.992801
# 48  -0.025557     -0.294619 -0.833471
# 54   3.213457      2.556872 -0.804757
# 58   0.973713     -0.294619 -0.765811
# 60  -2.575420      0.655878 -0.748814
# 63   0.732510     -1.245116 -0.731569
# 71  -1.059285     -0.294619 -0.646912
# 72   0.284561     -0.294619 -0.639485
# 3     2.671812        -0.268594 -1.168964
# 4     2.067569        -0.556569 -1.160795
# 6    10.438061        -0.716919 -1.130843
# 7     2.960325        -0.350405 -1.127130
# 8     3.461139        -0.707101 -1.123252
# 13    1.940551        -0.481303 -1.090165
# 19    3.459324         0.219000 -1.046764
# 23    1.964140        -0.206417 -0.993378
# 45    4.433735        -0.425671 -0.849560
# 52    1.541351        -0.402764 -0.809047
# 86   -0.333073         2.372267 -0.502846
# 90    3.818604        -0.298046 -0.488159
# 119   0.380043         1.436349 -0.334604
# 122   1.016948        -0.500937 -0.313399
# 131   0.320163         0.461161 -0.251928
# 137  -0.285894         3.373635 -0.229567
# 138   1.251024        -0.134424 -0.223544
# 203  -0.064520         2.418082  0.374007
# 262  -0.235087         1.050201  2.020942
# 263  -0.336702         0.745863  2.381601
# 264  -0.336702         0.614966  2.485483
# 265  -0.327629         2.486803  3.411430
# 266  -0.336702         0.906213  4.167898
# 267  -0.296782         1.848677  4.420054
# 268  -0.271378         1.377445  4.652572
# 269  -0.329444         8.812435  4.652572
# 270  -0.327629         1.027293  5.080809
# Outliers in the trivariate analysis of Reviews, Type_Numeric, and Price:
#        Reviews  Type_Numeric     Price
# 0     6.611187     -1.245116 -1.268555
# 1     2.214547     -1.245116 -1.221524
# 3     2.671812     -1.245116 -1.168964
# 4     2.067569     -0.294619 -1.160795
# 6    10.438061     -1.245116 -1.130843
# 7     2.960325     -1.245116 -1.127130
# 8     3.461139     -1.245116 -1.123252
# 13    1.940551     -1.245116 -1.090165
# 19    3.459324     -1.245116 -1.046764
# 23    1.964140      0.655878 -0.993378
# 45    4.433735     -1.245116 -0.849560
# 52    1.541351      0.655878 -0.809047
# 85   -0.109884      1.606375 -0.516625
# 90    3.818604      0.655878 -0.488159
# 95   -0.115327      1.606375 -0.455732
# 122   1.016948      0.655878 -0.313399
# 138   1.251024      0.655878 -0.223544
# 228  -0.177022      2.556872  0.804058
# 229  -0.331258      2.556872  0.804306
# 265  -0.327629     -1.245116  3.411430
# 266  -0.336702     -1.245116  4.167898
# 267  -0.296782      0.655878  4.420054
# 268  -0.271378     -2.195613  4.652572
# 269  -0.329444     -1.245116  4.652572
# 270  -0.327629     -1.245116  5.080809
# Outliers in the trivariate analysis of Number_Of_Pages, Type_Numeric, and Price:
#      Number_Of_Pages  Type_Numeric     Price
# 2          -1.391042     -0.294619 -1.214015
# 4          -0.556569     -0.294619 -1.160795
# 58         -1.161971     -0.294619 -0.765811
# 85         -0.612200      1.606375 -0.516625
# 86          2.372267      0.655878 -0.502846
# 95         -0.867451      1.606375 -0.455732
# 137         3.373635     -1.245116 -0.229567
# 203         2.418082      0.655878  0.374007
# 228         1.020749      2.556872  0.804058
# 229         0.349898      2.556872  0.804306
# 253         2.162831      0.655878  1.372399
# 257         0.814585      0.655878  1.510029
# 262         1.050201     -1.245116  2.020942
# 263         0.745863     -1.245116  2.381601
# 264         0.614966     -1.245116  2.485483
# 265         2.486803     -1.245116  3.411430
# 266         0.906213     -1.245116  4.167898
# 267         1.848677      0.655878  4.420054
# 268         1.377445     -2.195613  4.652572
# 269         8.812435     -1.245116  4.652572
# 270         1.027293     -1.245116  5.080809
